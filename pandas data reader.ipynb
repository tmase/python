# %%
#https://pandas-datareader.readthedocs.io/en/latest/remote_data.html
import pandas_datareader.data as web
import datetime
import pandas as pd
import matplotlib.pyplot as plt

# %%
start = datetime.datetime(2010, 1, 1)
end = datetime.datetime(2018, 5, 1)
gdp = web.DataReader('GDP', 'fred', start, end)

# %%
gdp.head()
# Out:
#                   GDP
# DATE
# 2010-01-01  14681.063
# 2010-04-01  14888.600
# 2010-07-01  15057.660
# 2010-10-01  15230.208
# 2011-01-01  15238.371

# %%
plt.plot(gdp.index, gdp['GDP'])
plt.title('U.S. GDP')
plt.ylabel('($T)');
plt.show()

# %%
# Multiple series:
inflation = web.DataReader(['CPIAUCSL', 'CPILFESL'], 'fred', start, end)
inflation.head()
# Out:
#             CPIAUCSL  CPILFESL
# DATE
# 2010-01-01   217.488   220.633
# 2010-02-01   217.281   220.731
# 2010-03-01   217.353   220.783
# 2010-04-01   217.403   220.822
# 2010-05-01   217.290   220.962

# %%
start = datetime.datetime(1970, 1, 1)
end = datetime.datetime(2018, 5, 1)
interest_rate = web.DataReader('FEDFUNDS', 'fred', start, end)

# %%
plt.plot(interest_rate.index, interest_rate['FEDFUNDS'])
plt.title('Effective Federal Funds Rate')
plt.ylabel('(%)');
plt.show()

# %%
interest_rate.loc['1980':'1985']
# Out:
#             FEDFUNDS
# DATE
# 1980-01-01     13.82
# 1980-02-01     14.13
# 1980-03-01     17.19
# 1980-04-01     17.61
# 1980-05-01     10.98
# 1980-06-01      9.47
# 1980-07-01      9.03
# 1980-08-01      9.61
# 1980-09-01     10.87
# 1980-10-01     12.81
# 1980-11-01     15.85
# 1980-12-01     18.90
# 1981-01-01     19.08
# 1981-02-01     15.93
# 1981-03-01     14.70
# 1981-04-01     15.72
# 1981-05-01     18.52
# 1981-06-01     19.10
# 1981-07-01     19.04
# 1981-08-01     17.82
# 1981-09-01     15.87
# 1981-10-01     15.08
# 1981-11-01     13.31
# 1981-12-01     12.37
# 1982-01-01     13.22
# 1982-02-01     14.78
# 1982-03-01     14.68
# 1982-04-01     14.94
# 1982-05-01     14.45
# 1982-06-01     14.15
# ...              ...
# 1983-07-01      9.37
# 1983-08-01      9.56
# 1983-09-01      9.45
# 1983-10-01      9.48
# 1983-11-01      9.34
# 1983-12-01      9.47
# 1984-01-01      9.56
# 1984-02-01      9.59
# 1984-03-01      9.91
# 1984-04-01     10.29
# 1984-05-01     10.32
# ...

# %%
interest_rate.max()
# Out:
# FEDFUNDS    19.1
# dtype: float64

# %%
interest_rate[interest_rate.values == 19.1]
# Out:
#             FEDFUNDS
# DATE
# 1981-06-01      19.1

# %%
#China GDP: MKTGDPCNA646NWDB

start = datetime.datetime(2010, 1, 1)
end = datetime.datetime(2018, 5, 1)
gdp_compare = web.DataReader(['MKTGDPUSA646NWDB', 'MKTGDPCNA646NWDB'], 'fred', start, end)

# %%
gdp_tril = gdp_compare.iloc[1:] / 1000000000000

# %%
plt.plot(gdp_tril.index, gdp_tril['MKTGDPUSA646NWDB'], gdp_tril['MKTGDPCNA646NWDB'])
plt.title('GDP of US vs China')
plt.ylabel('($T)');
plt.show()
